# %% [markdown]
# <a href="https://colab.research.google.com/github/BaidyaSubhadip/Eavesdropping101/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore  ... HasCrCard IsActiveMember  EstimatedSalary  Exited
# 0   0    15674932  Okwudilichukwu          668  ...       1.0            0.0        181449.97       0
# 1   1    15749177   Okwudiliolisa          627  ...       1.0            1.0         49503.50       0
# 2   2    15694510           Hsueh          678  ...       1.0            0.0        184866.69       0
# 3   3    15741417             Kao          581  ...       1.0            1.0         84560.88       0
# 4   4    15766172       Chiemenam          716  ...       1.0            1.0         15068.83       0
#
# [5 rows x 14 columns]

# %%
df['Geography'] =df['Geography'].replace({'Spain': 1, 'France': 2, 'Germany':3})
df['Gender'] =df['Gender'].replace({'Male': 1, 'Female': 0})

# %%
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore  ...  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0   0    15674932  Okwudilichukwu          668  ...        1.0             0.0        181449.97       0
# 1   1    15749177   Okwudiliolisa          627  ...        1.0             1.0         49503.50       0
# 2   2    15694510           Hsueh          678  ...        1.0             0.0        184866.69       0
# 3   3    15741417             Kao          581  ...        1.0             1.0         84560.88       0
# 4   4    15766172       Chiemenam          716  ...        1.0             1.0         15068.83       0
#
# [5 rows x 14 columns]

# %%
scaler = StandardScaler()

columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

df[columns] = scaler.fit_transform(df[columns])

# %%
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore  ...  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0   0    15674932  Okwudilichukwu     0.144135  ...        1.0             0.0         1.369486       0
# 1   1    15749177   Okwudiliolisa    -0.367706  ...        1.0             1.0        -1.254085       0
# 2   2    15694510           Hsueh     0.268974  ...        1.0             0.0         1.437422       0
# 3   3    15741417             Kao    -0.941966  ...        1.0             1.0        -0.557018       0
# 4   4    15766172       Chiemenam     0.743362  ...        1.0             1.0        -1.938770       0
#
# [5 rows x 14 columns]

# %%
X = df.drop(['Surname', 'id','Exited','CustomerId'], axis=1)
Y = df['Exited']

# %%
from tensorflow import keras
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(10,)),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X,Y,validation_split=0.1,epochs=20)
# Out:
# Epoch 1/20
# 4642/4642 [==============================] - 9s 2ms/step - loss: 0.3644 - accuracy: 0.8432 - val_loss: 0.3367 - val_accuracy: 0.8603
# Epoch 2/20
# 4642/4642 [==============================] - 9s 2ms/step - loss: 0.3340 - accuracy: 0.8594 - val_loss: 0.3304 - val_accuracy: 0.8618
# Epoch 3/20
# 4642/4642 [==============================] - 12s 3ms/step - loss: 0.3300 - accuracy: 0.8607 - val_loss: 0.3289 - val_accuracy: 0.8640
# Epoch 4/20
# 4642/4642 [==============================] - 9s 2ms/step - loss: 0.3285 - accuracy: 0.8618 - val_loss: 0.3263 - val_accuracy: 0.8649
# Epoch 5/20
# 4642/4642 [==============================] - 8s 2ms/step - loss: 0.3272 - accuracy: 0.8626 - val_loss: 0.3261 - val_accuracy: 0.8660
# Epoch 6/20
# 4642/4642 [==============================] - 8s 2ms/step - loss: 0.3262 - accuracy: 0.8631 - val_loss: 0.3232 - val_accuracy: 0.8658
# Epoch 7/20
# ...

# %%
test = pd.read_csv('test.csv')

# %%
test['Gender'] = test['Gender'].replace({'Male': 1, 'Female': 0})
test['Geography'] = test['Geography'].replace({'Spain': 1, 'France': 2, 'Germany':3})

# %%
test.head()
# Out:
#        id  CustomerId    Surname  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0  165034    15773898   Lucchese  ...        0.0             1.0        160976.75
# 1  165035    15782418       Nott  ...        1.0             0.0         72549.27
# 2  165036    15807120         K?  ...        1.0             0.0        138882.09
# 3  165037    15808905  O'Donnell  ...        1.0             0.0        113931.57
# 4  165038    15607314    Higgins  ...        1.0             0.0        139431.00
#
# [5 rows x 13 columns]

# %%
columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

test[columns] = scaler.fit_transform(test[columns])

# %%
test.head()
# Out:
#        id  CustomerId    Surname  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0  165034    15773898   Lucchese  ...        0.0             1.0         0.967874
# 1  165035    15782418       Nott  ...        1.0             0.0        -0.790939
# 2  165036    15807120         K?  ...        1.0             0.0         0.528413
# 3  165037    15808905  O'Donnell  ...        1.0             0.0         0.032150
# 4  165038    15607314    Higgins  ...        1.0             0.0         0.539331
#
# [5 rows x 13 columns]

# %%
import csv

# Data to be written to the CSV file
data = [
    ['id', 'Prediction'],
]

# Specify the file path
file_path = '/content/prediction.csv'

# Writing to the CSV file
with open(file_path, 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(data)

# Print a message to confirm that the file has been created
print(f'CSV file "{file_path}" created successfully.')
# Out:
# CSV file "/content/prediction.csv" created successfully.

# %%
# Iterate through all rows
for index, row in test.iterrows():
    # 'row' is a pandas Series representing the entire row
    row =  row.tolist()  # 'your_variable' now contains the entire row as a pandas Series
    # Now, you can use 'your_variable' as needed within the loop
    print(row)
    break
# Out:
# [165034, 15773898, 'Lucchese', -0.8781764991210168, 2, 0, -1.7065044671182898, -1.0678874933249831, -0.8812735688945736, 0.8200297946002656, 0.0, 1.0, 0.9678735144276992]

# %%
test_input = test.drop(['Surname', 'id','CustomerId'], axis=1)

# %%
test_input
# Out:
#         CreditScore  Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.878176          2       0  ...        0.0             1.0         0.967874
# 1          0.329567          2       0  ...        1.0             0.0        -0.790939
# 2         -0.006609          2       0  ...        1.0             0.0         0.528413
# 3          0.304665          2       1  ...        1.0             0.0         0.032150
# 4          1.188684          3       1  ...        1.0             0.0         0.539331
# ...             ...        ...     ...  ...        ...             ...              ...
# 110018    -1.077392          1       1  ...        1.0             1.0         0.711510
# 110019    -1.015137          2       0  ...        1.0             1.0        -1.394946
# 110020     0.690645          2       1  ...        1.0             0.0        -1.909981
# 110021     0.653292          2       0  ...        1.0             1.0         0.924908
# ...

# %%
# Iterate through all rows
for index, row in test.iterrows():
    row =  row.tolist()
    test_input = row[3:]
    test_input = np.array(test_input)
    test_input = test_input.reshape((1, 10))
    #print(row)
    #print(test_input)
    current_id = row[0]
    current_prediction = model.predict(test_input)
    #print(current_prediction.shape)
    #print(type(current_prediction))
    #print(current_prediction[0][0])

    #break
    #print(current_id)
    #print(test_input.shape)
    #print(current_prediction)
    data.append([current_id, current_prediction[0][0]])

#Append data to the CSV file
with open(file_path, 'a', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(data[1:])  # Skip the header when appending

print('Data appended to the CSV file.')
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step
# ...
# ...
# 1/1 [==============================] - 0s 25ms/step
